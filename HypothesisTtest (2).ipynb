# %%
#Financial literacy
# importing the pandas library 
import pandas as pd 
csv_file = "C:\\Users\\gisfe\\Downloads\\QUESTIONNAIRE DATASET.csv"
# reading the csv file 
df = pd.read_csv(csv_file) 
  
# updating the column value/data 
df['FinancialLiteracyScore'] = 1 + 2 * (df['Do you make day-to-day decisions about your own money?'] == 'Yes')
+ 1 * (df['I tend to live for today and let tomorrow take care of itself. '])+ 1 * (df['I find it more satisfying to spend money than to save it for the long term. ']) - 1 * (df['I pay my bills on time.']) -1 * (df['I am prepared to risk some of my own money when saving or making an investment.'])
-1 * (df['I keep a close personal watch on my finance'])-1 * (df['I set long term financial goals and strive to achieve them. '])-1 * (df['I have money left over to be spent at the end of the month '])-1 * (df['Before I buy something I carefully consider whether I can afford it '])
-1 * (df['Sometimes people find that their income does not quite cover their living costs. In the last 12 months, has this happened to you?'])
+1 * (df['Some people set themselves financial goals, such as paying university fees, buying a car or becoming debt free. Do you (personally, or with your family) have any financial goals? ']== 'Yes')



# writing into the file 
df.to_csv("C:\\Users\\gisfe\\Downloads\\QUESTIONNAIRE DATASET.csv", index=False) 
  
print(df)
# Out:
#               Timestamp     Formal Education in  Gender        Age  \
# 0   11/27/2023 14:42:09                   Other    Male  21-30 yrs
# 1   11/27/2023 14:44:29                   Other    Male  21-30 yrs
# 2   11/27/2023 14:45:08                   Other  Female  15-20 yrs
# 3   11/27/2023 14:51:24  Finance related domain    Male  21-30 yrs
# 4   11/27/2023 14:55:14                   Other  Female  21-30 yrs
# 5   11/27/2023 14:55:19  Finance related domain    Male  21-30 yrs
# 6   11/27/2023 14:58:34  Finance related domain    Male  21-30 yrs
# 7   11/27/2023 14:59:26                   Other    Male  21-30 yrs
# 8   11/27/2023 15:43:51                   Other  Female  21-30 yrs
# 9   11/27/2023 16:08:39                   Other  Female  21-30 yrs
# 10  11/29/2023 10:39:21  Finance related domain  Female  21-30 yrs
# 11  11/29/2023 11:19:26                   Other  Female  21-30 yrs
# 12  11/29/2023 11:20:32  Finance related domain  Female  21-30 yrs
# ...

# %%
#EducationScore
# importing the pandas library 
import pandas as pd 
csv_file = "C:\\Users\\gisfe\\Downloads\\QUESTIONNAIRE DATASET.csv"
# reading the csv file 
df = pd.read_csv(csv_file) 
  
# updating the column value/data 
df['EducationScore'] = 4 * (df['Formal Education in'] == 'Finance related domain')+ 1 * (df['Formal Education in'] == 'Other')+ 1 * (df['Education Level']== 'Bachelors') + 2 * (df['Education Level']== 'Masters') + 3 * (df['Education Level']== 'Phd/Doctorate')
# writing into the file 
df.to_csv("C:\\Users\\gisfe\\Downloads\\QUESTIONNAIRE DATASET.csv", index=False) 
  
print(df)
# Out:
#               Timestamp     Formal Education in  Gender        Age  \
# 0   11/27/2023 14:42:09                   Other    Male  21-30 yrs
# 1   11/27/2023 14:44:29                   Other    Male  21-30 yrs
# 2   11/27/2023 14:45:08                   Other  Female  15-20 yrs
# 3   11/27/2023 14:51:24  Finance related domain    Male  21-30 yrs
# 4   11/27/2023 14:55:14                   Other  Female  21-30 yrs
# 5   11/27/2023 14:55:19  Finance related domain    Male  21-30 yrs
# 6   11/27/2023 14:58:34  Finance related domain    Male  21-30 yrs
# 7   11/27/2023 14:59:26                   Other    Male  21-30 yrs
# 8   11/27/2023 15:43:51                   Other  Female  21-30 yrs
# 9   11/27/2023 16:08:39                   Other  Female  21-30 yrs
# 10  11/29/2023 10:39:21  Finance related domain  Female  21-30 yrs
# 11  11/29/2023 11:19:26                   Other  Female  21-30 yrs
# 12  11/29/2023 11:20:32  Finance related domain  Female  21-30 yrs
# ...

# %%
#counting the number of financial products known
import pandas as pd

# Load the CSV file
csv_file = "C:\\Users\\gisfe\\Downloads\\QUESTIONNAIRE DATASET.csv"
df = pd.read_csv(csv_file)

# Assuming 'Values' is the column containing comma-separated values
df['Count_financialProductsKnown'] = df['Please can you tell me whether you have heard of any of these types of financial products.'].str.count(',') + 1

# Save the modified DataFrame to a new CSV file
df.to_csv("C:\\Users\\gisfe\\Downloads\\QUESTIONNAIRE DATASET.csv", index=False)

# %%
#count of number of producttypes (personally or jointly) held?
#counting the number of financial products owned
import pandas as pd

# Load the CSV file
csv_file = "C:\\Users\\gisfe\\Downloads\\QUESTIONNAIRE DATASET.csv"
df = pd.read_csv(csv_file)

# Assuming 'Values' is the column containing comma-separated values
df['Count_financialProductsOwned'] = df['Now can you tell me whether you currently hold any of these types of products (personally or jointly)?'].str.count(',') + 1

# Save the modified DataFrame to a new CSV file
df.to_csv("C:\\Users\\gisfe\\Downloads\\QUESTIONNAIRE DATASET.csv", index=False)

# %%
#count of number of producttypes (personally or jointly) held?
#counting the number of financial products owned
import pandas as pd

# Load the CSV file
csv_file = "C:\\Users\\gisfe\\Downloads\\QUESTIONNAIRE DATASET.csv"
df = pd.read_csv(csv_file)

# Assuming 'Values' is the column containing comma-separated values
df['Count_financialProductsChosen'] = df['In the  last two years, which of the following types of financial products have you chosen (Personally or jointly) whether or not you still hold them…'].str.count(',') + 1

# Save the modified DataFrame to a new CSV file
df.to_csv("C:\\Users\\gisfe\\Downloads\\QUESTIONNAIRE DATASET.csv", index=False)

# %%
#Financial knowledge
# importing the pandas library 
import pandas as pd 
csv_file ="C:\\Users\\gisfe\\Downloads\\QUESTIONNAIRE DATASET.csv"
# reading the csv file 
df = pd.read_csv(csv_file) 

  
# updating the column value/data 
df['Financialknowledge'] = 1 + 1 * (df['Do you have any informal education in finance ? '] == 'Youtube videos')+ 1 * (df['Do you have any informal education in finance ? '] == 'Free courses')+ 2 * (df['Do you have any informal education in finance ? '] == 'Paid courses')
+ 1 * (df['Count_financialProductsKnown'])+ 2* (df['Count_financialProductsOwned']) + 2 * (df['Count_financialProductsChosen']) 


# writing into the file 
df.to_csv("C:\\Users\\gisfe\\Downloads\\QUESTIONNAIRE DATASET.csv", index=False) 
  
print(df)
# Out:
#               Timestamp     Formal Education in  Gender        Age  \
# 0   11/27/2023 14:42:09                   Other    Male  21-30 yrs
# 1   11/27/2023 14:44:29                   Other    Male  21-30 yrs
# 2   11/27/2023 14:45:08                   Other  Female  15-20 yrs
# 3   11/27/2023 14:51:24  Finance related domain    Male  21-30 yrs
# 4   11/27/2023 14:55:14                   Other  Female  21-30 yrs
# 5   11/27/2023 14:55:19  Finance related domain    Male  21-30 yrs
# 6   11/27/2023 14:58:34  Finance related domain    Male  21-30 yrs
# 7   11/27/2023 14:59:26                   Other    Male  21-30 yrs
# 8   11/27/2023 15:43:51                   Other  Female  21-30 yrs
# 9   11/27/2023 16:08:39                   Other  Female  21-30 yrs
# 10  11/29/2023 10:39:21  Finance related domain  Female  21-30 yrs
# 11  11/29/2023 11:19:26                   Other  Female  21-30 yrs
# 12  11/29/2023 11:20:32  Finance related domain  Female  21-30 yrs
# ...

# %%
#map 'How much do you spend on food every day on an average?' values to 1234
import pandas as pd

# Create a sample DataFrame
csv_file = "C:\\Users\\gisfe\\Downloads\\QUESTIONNAIRE DATASET.csv"
# reading the csv file 
df = pd.read_csv(csv_file)

# %%
#map 'How much do you spend on travel every week on an average?' values to 1234
import pandas as pd

# Create a sample DataFrame
csv_file = "C:\\Users\\gisfe\\Downloads\\QUESTIONNAIRE DATASET.csv"
# reading the csv file 
df = pd.read_csv(csv_file)

# %%
#LifestyleScore
# importing the pandas library 
import pandas as pd 
csv_file = "C:\\Users\\gisfe\\Downloads\\QUESTIONNAIRE DATASET.csv"
# reading the csv file 
df = pd.read_csv(csv_file) 



# Define a mapping for the values
value_mapping1 = {'Less than 100': 1, '100 - 250': 2, '250 - 500': 3, 'More than 500': 4}


# Map the values in the 'Column' based on the defined mapping
df['How much do you spend on food every day on an average?'] = df['How much do you spend on food every day on an average?'].map(value_mapping1)
#df['Background'] = df['How much do you spend on food every day on an average?'].map(value_mapping1)
# Print the modified DataFrame
print(df)

# writing into the file 
df.to_csv("C:\\Users\\gisfe\\Downloads\\QUESTIONNAIRE DATASET.csv", index=False) 
  
# Map the values in the 'Column' based on the defined mapping
df['How much do you spend on travel every week on an average?'] = df['How much do you spend on travel every week on an average?'].map(value_mapping1)


# Define a mapping for the values
value_mapping2 = {'Less than 1000': 1, '1000 - 2500': 2, '2500 - 5000': 3, 'More than 5000': 4}

# Map the values in the 'Column' based on the defined mapping
df['How much do you spend on clothes and accessories every month on an average?'] = df['How much do you spend on clothes and accessories every month on an average?'].map(value_mapping2)
# Map the values in the 'Column' based on the defined mapping
df['How much do you spend on daily neccesseties every month on an average?'] = df['How much do you spend on clothes and accessories every month on an average?'].map(value_mapping2)



  
# updating the column value/data 
    
df['LifestyleScore'] = 1 + 2 * (df['Which of the following statements best describes how you purchase items'] == 'I consider products from different companies before buying, I consider only affordable options')
+ 3 * (df['Which of the following statements best describes how you purchase items'] == "I don't consider buying unnecessary products")
+ 1 * (df['Which of the following statements best describes how you purchase items'] == "I am loyal to certain brands and products, I don't consider other affordable options")
+ 1 * (df['How much do you spend on food every day on an average?'])+ 1 * (df['How much do you spend on travel every week on an average?'])
+ 1 * (df['How much do you spend on clothes and accessories every month on an average?'])+ 1* (df['How much do you spend on daily neccesseties every month on an average?'])  


# writing into the file 
df.to_csv("C:\\Users\\gisfe\\Downloads\\QUESTIONNAIRE DATASET.csv", index=False) 
  
print(df)
# Out:
#               Timestamp     Formal Education in  Gender        Age  \
# 0   11/27/2023 14:42:09                   Other    Male  21-30 yrs
# 1   11/27/2023 14:44:29                   Other    Male  21-30 yrs
# 2   11/27/2023 14:45:08                   Other  Female  15-20 yrs
# 3   11/27/2023 14:51:24  Finance related domain    Male  21-30 yrs
# 4   11/27/2023 14:55:14                   Other  Female  21-30 yrs
# 5   11/27/2023 14:55:19  Finance related domain    Male  21-30 yrs
# 6   11/27/2023 14:58:34  Finance related domain    Male  21-30 yrs
# 7   11/27/2023 14:59:26                   Other    Male  21-30 yrs
# 8   11/27/2023 15:43:51                   Other  Female  21-30 yrs
# 9   11/27/2023 16:08:39                   Other  Female  21-30 yrs
# 10  11/29/2023 10:39:21  Finance related domain  Female  21-30 yrs
# 11  11/29/2023 11:19:26                   Other  Female  21-30 yrs
# 12  11/29/2023 11:20:32  Finance related domain  Female  21-30 yrs
# ...

# %%
df_score = df[ 
    (df['FinancialLiteracyScore'].notnull()) & 
    (df['LifestyleScore'].notnull())
][['FinancialLiteracyScore','LifestyleScore']]
df_score
# Out:
#     FinancialLiteracyScore  LifestyleScore
# 0                        3               3
# 1                        1               1
# 2                        1               3
# 3                        3               1
# 4                        1               3
# 5                        3               3
# 6                        1               1
# 7                        3               3
# 8                        3               1
# 9                        3               3
# 10                       3               3
# 11                       3               3
# 12                       3               1
# 13                       3               1
# 14                       3               3
# 15                       3               3
# 16                       1               1
# 17                       1               3
# 18                       3               3
# 19                       3               3
# 20                       3               1
# ...

# %%
from scipy.stats import ttest_rel

test_statistic, p_value = ttest_rel(df_score['FinancialLiteracyScore'], df_score['LifestyleScore'],alternative='less')

print("test statistic= ",test_statistic)
print("P value= ",p_value)

if p_value < 0.05:
    print("\nWe Reject Null Hypothesis")
else:
    print("\nWe Accept Null Hypothesis")
# Out:
# test statistic=  0.9412258178930584
# P value=  0.8232856735633596
#
# We Accept Null Hypothesis

# %%
df_score = df[ 
    (df['FinancialLiteracyScore'].notnull()) & 
    (df['EducationScore'].notnull())
][['FinancialLiteracyScore','EducationScore']]
df_score
# Out:
#     FinancialLiteracyScore  EducationScore
# 0                        3               2
# 1                        1               3
# 2                        1               3
# 3                        3               6
# 4                        1               3
# 5                        3               6
# 6                        1               4
# 7                        3               2
# 8                        3               3
# 9                        3               2
# 10                       3               6
# 11                       3               2
# 12                       3               6
# 13                       3               3
# 14                       3               3
# 15                       3               2
# 16                       1               3
# 17                       1               2
# 18                       3               5
# 19                       3               6
# 20                       3               3
# ...

# %%
from scipy.stats import ttest_rel

test_statistic, p_value = ttest_rel(df_score['FinancialLiteracyScore'], df_score['EducationScore'],alternative='less')

print("test statistic= ",test_statistic)
print("P value= ",p_value)

if p_value < 0.05:
    print("\nWe Reject Null Hypothesis")
else:
    print("\nWe Accept Null Hypothesis")
# Out:
# test statistic=  -4.178554470186725
# P value=  0.00010106296517453298
#
# We Reject Null Hypothesis

# %%
df_score = df[ 
    (df['FinancialLiteracyScore'].notnull()) & 
    (df['Financialknowledge'].notnull())
][['FinancialLiteracyScore','Financialknowledge']]
df_score
# Out:
#     FinancialLiteracyScore  Financialknowledge
# 0                        3                   2
# 1                        1                   3
# 2                        1                   2
# 3                        3                   1
# 4                        1                   2
# 5                        3                   2
# 6                        1                   2
# 7                        3                   2
# 8                        3                   1
# 9                        3                   1
# 10                       3                   1
# 11                       3                   1
# 12                       3                   1
# 13                       3                   2
# 14                       3                   1
# 15                       3                   2
# 16                       1                   1
# 17                       1                   2
# 18                       3                   2
# ...

# %%
from scipy.stats import ttest_rel

test_statistic, p_value = ttest_rel(df_score['FinancialLiteracyScore'], df_score['Financialknowledge'],alternative='less')

print("test statistic= ",test_statistic)
print("P value= ",p_value)

if p_value < 0.05:
    print("\nWe Reject Null Hypothesis")
else:
    print("\nWe Accept Null Hypothesis")
# Out:
# test statistic=  3.772791334190874
# P value=  0.9996809489001864
#
# We Accept Null Hypothesis

# %%
df.describe()
# Out:
#        Number of Members in Family  \
# count                    34.000000
# mean                      4.558824
# std                       2.389258
# min                       2.000000
# 25%                       3.000000
# 50%                       4.000000
# 75%                       5.000000
# max                      16.000000
#
#        How many members are responsible for managing household income?  \
# count                                          34.000000
# mean                                            2.176471
# std                                             1.381053
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             2.750000
# max                                             6.000000
#
#        I tend to live for today and let tomorrow take care of itself.   \
# ...

# %%
df.shape
# Out:
# (34, 45)
